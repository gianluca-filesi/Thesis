# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from linearmodels import PanelOLS
import plotly.express as px

sns.set_theme()

# %% [markdown]
# # Functions

# %%
def Pivoting(df): # Function to pivot the dataframe
    df_r = df.pivot(index=['CCode','year'], 
                       columns='indicator', 
                       values='value')
    df_r.reset_index(inplace=True)
    df_r.columns.name = None
    return df_r

# %%
def PrepareData(df,ind): # Function to prepare the data for analysis
    Panel = df.copy()
    shift = ind.replace('_value', '') + '_shifted'
    Panel[shift] = Panel.groupby('CCode')[ind].shift(1)
    Panel[shift].dropna(inplace=True) # Drop rows with NaN values
    return Panel

# %%
def Regression(Panel,independent_vars,dependent_var): # Function to run the regression
    L = ['CCode','year']
    L.extend(independent_vars)
    L.append(dependent_var)
    model_df = Panel[L].copy()
    model_df = model_df.set_index(['CCode', 'year'])
    model_df = model_df.dropna() # Drop rows with NaN values

    Y = model_df[dependent_var]
    X = model_df[independent_vars]
    X = sm.add_constant(X)

    mod_fe = PanelOLS(Y,X, entity_effects=True, time_effects=True)
    results = mod_fe.fit(cov_type='clustered',cluster_entity=True)

    print(results.summary)
    return None

# %% [markdown]
# # Data loading and preparation

# %% [markdown]
# ## Data loading

# %%
path = '/Users/gianlucafilesi/Library/CloudStorage/OneDrive-EDHEC/04 THESIS/Thesis/'

# %% [markdown]
# GDP per capita dataset source: https://data.worldbank.org/indicator/NY.GDP.PCAP.CD

# %%
gdp_pc = pd.read_csv(path+'GDP-PC.csv',skiprows=4) # Upload the GDP per capita data

# %% [markdown]
# HDR dataset source: https://hdr.undp.org/data-center/documentation-and-downloads

# %%
hdr = pd.read_excel(path+'hdr-data.xlsx') # Upload the HDR data
hdr.isnull().sum() # Check for missing values
# Out:
# countryIsoCode         0
# country                0
# indexCode              0
# index                  0
# dimension         186115
# indicatorCode          0
# indicator              0
# year                   7
# value                  0
# note              185973
# dtype: int64

# %% [markdown]
# Schooling dataset source: https://databrowser.uis.unesco.org/resources

# %%
schooling = pd.read_csv(path+'OPRI_DATA_NATIONAL.zip', dtype={'INDICATOR_ID': 'object'}, compression='zip')  # Upload the schooling data
schooling_labels = pd.read_csv(path+'OPRI_LABEL.csv') # Upload the schooling labels
# Out:
# /var/folders/pl/qxmk8x1d1m586z4_j013bvqw0000gn/T/ipykernel_9009/2136664546.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   schooling = pd.read_csv(path+'OPRI_DATA_NATIONAL.csv',dtype={'INDICATOR_ID': 'object'}) # Upload the schooling data

# %%
Labels = schooling_labels.iloc[0:18,0] # Get the labels for the schooling data
SCH = schooling.copy()
SCH = SCH[SCH['INDICATOR_ID'].isin(Labels)]
SCH = SCH.drop(columns=['MAGNITUDE','QUALIFIER'])
SCH = pd.merge(schooling_labels,SCH,how='left',on='INDICATOR_ID') # Merge the labels with the schooling data
SCH = SCH.rename(columns={'INDICATOR_LABEL_EN': 'indicator', 'COUNTRY_ID': 'CCode', 'YEAR': 'year', 'VALUE': 'value'}) # Rename the columns
SCH['year'] = pd.to_datetime(SCH['year'], format='%Y',errors='coerce').dt.year

# %%
Countries = {hdr['countryIsoCode'][i]:hdr['country'][i] for i in range(len(hdr))} # Create a dictionary to map country codes to country names

# %%
HDR = hdr.copy().drop(columns=['dimension','note','country']) # Drop unnecessary columns
HDR['year'] = pd.to_datetime(HDR['year'], format='%Y',errors='coerce').dt.year # Convert year to datetime format
HDR.rename(columns={'countryIsoCode':'CCode'},inplace=True) # Rename columns for consistency

# %%
'''
Since the HDR data contains multiple indices, we need to separate them into different dataframes.
We will create a dictionary to store these dataframes, where the keys are the index codes and the values are the corresponding dataframes.
'''
indecies = HDR['indexCode'].unique() # Get unique Country codes
grouped_dfs = {} # Create a dictionary to store dataframes for each index

for code in indecies:
    grouped_dfs[code] = HDR[HDR['indexCode'] == code].drop(columns=['indexCode', 'index']) # Drop unnecessary columns

GII = grouped_dfs.get('GII') # Get the GII dataframe
HDI = grouped_dfs.get('HDI') # Get the HDI dataframe
GDI = grouped_dfs.get('GDI') # Get the GDI dataframe
IHDI = grouped_dfs.get('IHDI') # Get the IHDI dataframe
PHDI = grouped_dfs.get('PHDI') # Get the PHDI dataframe
MPI = grouped_dfs.get('MPI') # Get the MPI dataframe

# %% [markdown]
# ## Pivoting

# %% [markdown]
# #### GII

# %% [markdown]
# GII explanation: https://hdr.undp.org/data-center/thematic-composite-indices/gender-inequality-index#/indicies/GII
#
# GII reflects gender-based disadvantage in three dimensions— reproductive health, empowerment and the labour market—for as many countries as data of reasonable quality allow. It shows the loss in potential human development due to inequality between female and male achievements in these dimensions. It ranges from 0, where women and men fare equally, to 1, where one gender fares as poorly as possible in all measured dimensions. GII values are computed using the association-sensitive inequality measure suggested by Seth (2009), which implies that the index is based on the general mean of general means of different orders—the first aggregation is by a geometric mean across dimensions; these means, calculated separately for women and men, are then aggregated using a harmonic mean across genders.

# %%
GII_r = Pivoting(GII) # Pivot the GII dataframe
GII_r.drop(columns=['GII Rank'],inplace=True) # Drop the GII Rank column
col_to_move = GII_r.pop('Gender Inequality Index (value)')
GII_r.insert(3, 'GII_value', col_to_move) # Move the GII value column to the 3rd position
GII_r
# Out:
#          CCode    year  \
# 0          AFG  1990.0
# 1          AFG  1991.0
# 2          AFG  1992.0
# 3          AFG  1993.0
# 4          AFG  1994.0
# ...        ...     ...
# 6801   ZZM.LDC  2022.0
# 6802  ZZN.SIDS  2020.0
# 6803  ZZN.SIDS  2022.0
# 6804  ZZO.OECD  2020.0
# 6805  ZZO.OECD  2022.0
#
#       Adolescent Birth Rate (births per 1,000 women ages 15-19)  GII_value  \
# 0                                               142.960                NaN
# 1                                               147.525                NaN
# 2                                               147.521                NaN
# 3                                               147.896                NaN
# 4                                               155.669                NaN
# ...                                                 ...                ...
# 6801                                             92.400              0.556
# 6802                                                NaN                NaN
# 6803                                             50.600              0.457
# 6804                                                NaN                NaN
# 6805                                             18.500              0.194
#
#       Labour force participation rate, female (% ages 15 and older)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6801                                               50.4
# 6802                                                NaN
# 6803                                               51.4
# 6804                                                NaN
# 6805                                               53.0
#
#       Labour force participation rate, male (% ages 15 and older)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6801                                               75.5
# 6802                                                NaN
# 6803                                               69.8
# 6804                                                NaN
# 6805                                               68.7
#
#       Maternal Mortality Ratio (deaths per 100,000 live births)  \
# 0                                              1377.859
# 1                                              1392.786
# 2                                              1451.594
# 3                                              1368.816
# 4                                              1375.091
# ...                                                 ...
# 6801                                                NaN
# 6802                                            203.000
# 6803                                                NaN
# 6804                                             21.000
# 6805                                                NaN
#
#       Population with at least some secondary education, female (% ages 25 and older)  \
# 0                                                 1.108
# 1                                                 1.221
# 2                                                 1.335
# 3                                                 1.449
# 4                                                 1.562
# ...                                                 ...
# 6801                                             23.400
# 6802                                                NaN
# 6803                                             58.800
# 6804                                                NaN
# 6805                                             86.700
#
#       Population with at least some secondary education, male (% ages 25 and older)  \
# 0                                                 7.899
# 1                                                 8.138
# 2                                                 8.377
# 3                                                 8.616
# 4                                                 8.855
# ...                                                 ...
# 6801                                             33.800
# 6802                                                NaN
# 6803                                             62.300
# 6804                                                NaN
# 6805                                             89.300
#
#       Share of seats in parliament, female (% held by women)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6801                                               25.1
# 6802                                                NaN
# 6803                                               27.0
# 6804                                                NaN
# 6805                                               32.7
#
#       Share of seats in parliament, male (% held by men)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6801                                                NaN
# 6802                                                NaN
# 6803                                                NaN
# 6804                                                NaN
# 6805                                                NaN
#
# [6806 rows x 11 columns]

# %% [markdown]
# It will be useful later to have Countries grouped in categeories for data exploration. With this aim, GII will be splitted in 4 categories, based on its quartile.
# * $GII\ge q_{0.75}$: not-balanced country
# * $GII\in[q_{0.5},q_{0.75})$: medium-balanced country
# * $GII\in[q_{0.5},q_{0.75})$: balanced country
# * $GII < q_{0.25}$: very-balanced country

# %%
GII_r['GII_Category'] = pd.qcut(GII_r['GII_value'], q=4, labels=['VB', 'B', 'MB', 'NB'])

# %% [markdown]
# #### GDI

# %% [markdown]
# GDI explanation: https://hdr.undp.org/gender-development-index#/indicies/GDI
#
# GDI measures gender inequalities in achievement in three basic dimensions of human development: health, measured by female and male life expectancy at birth; education, measured by female and male expected years of schooling for children and female and male mean years of schooling for adults ages 25 years and older; and command over economic resources, measured by female and male estimated earned income.

# %%
GDI_r = Pivoting(GDI) # Pivot the GDI dataframe
col_to_move = GDI_r.pop('Gender Development Index (value)') # Move the GDI value column to the 3rd position
GDI_r.insert(3, 'GDI_value', col_to_move)
col_to_move = GDI_r.pop('GDI Group') # Move the GDI Group column to the 4th position
GDI_r.insert(4, 'GDI Group', col_to_move)
GDI_r
# Out:
#           CCode    year  Expected Years of Schooling, female (years)  \
# 0           AFG  1990.0                                        2.117
# 1           AFG  1991.0                                        2.246
# 2           AFG  1992.0                                        2.383
# 3           AFG  1993.0                                        2.528
# 4           AFG  1994.0                                        2.682
# ...         ...     ...                                          ...
# 6797  ZZK.WORLD  2022.0                                       13.082
# 6798     ZZL.DC  2022.0                                       12.600
# 6799    ZZM.LDC  2022.0                                        9.900
# 6800   ZZN.SIDS  2022.0                                       12.900
# 6801   ZZO.OECD  2022.0                                       17.100
#
#       GDI_value  GDI Group  Expected Years of Schooling, male (years)  \
# 0           NaN        NaN                                      4.533
# 1           NaN        NaN                                      4.768
# 2           NaN        NaN                                      5.016
# 3           NaN        NaN                                      5.277
# 4           NaN        NaN                                      5.551
# ...         ...        ...                                        ...
# 6797      0.951        NaN                                     12.908
# 6798      0.929        NaN                                     12.500
# 6799      0.890        NaN                                     10.300
# 6800      0.979        NaN                                     12.300
# 6801      0.984        NaN                                     16.100
#
#       Gross National Income Per Capita, female (2017 PPP$)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6797                                          12515.518
# 6798                                           7283.000
# 6799                                           2042.000
# 6800                                          13079.000
# 6801                                          36106.000
#
#       Gross National Income Per Capita, male (2017 PPP$)  HDI female  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                                   NaN          NaN
# 3                                                   NaN          NaN
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 6797                                          22034.766        0.719
# 6798                                          14943.000        0.716
# 6799                                           4054.000        0.509
# 6800                                          19712.000        0.722
# 6801                                          56848.000        0.898
#
#       HDI male  Life Expectancy at Birth, female (years)  \
# 0          NaN                                    48.397
# 1          NaN                                    49.144
# 2          NaN                                    50.320
# 3          NaN                                    52.739
# 4          NaN                                    53.544
# ...        ...                                       ...
# 6797     0.756                                    74.532
# 6798     0.665                                    72.900
# 6799     0.572                                    67.400
# 6800     0.738                                    74.300
# 6801     0.912                                    82.900
#
#       Life Expectancy at Birth, male (years)  \
# 0                                     43.709
# 1                                     44.353
# 2                                     45.070
# 3                                     50.216
# 4                                     49.531
# ...                                      ...
# 6797                                  69.599
# 6798                                  68.200
# 6799                                  62.500
# 6800                                  69.000
# 6801                                  77.400
#
#       Mean Years of Schooling, female (years)  \
# 0                                       0.202
# 1                                       0.219
# 2                                       0.236
# 3                                       0.254
# 4                                       0.271
# ...                                       ...
# 6797                                    8.231
# 6798                                    7.100
# 6799                                    4.300
# 6800                                    8.500
# 6801                                   12.100
#
#       Mean Years of Schooling, male (years)
# 0                                     1.494
# 1                                     1.579
# 2                                     1.664
# 3                                     1.749
# 4                                     1.833
# ...                                     ...
# 6797                                  9.118
# 6798                                  8.200
# 6799                                  5.900
# 6800                                  8.800
# 6801                                 12.300
#
# [6802 rows x 14 columns]

# %% [markdown]
# #### HDI

# %% [markdown]
# HDI explanation: https://hdr.undp.org/data-center/human-development-index#/indicies/HDI
#
#
# The Human Development Index (HDI) is a summary measure of average achievement in key dimensions of human development: a long and healthy life, being knowledgeable and having a decent standard of living. The HDI is the geometric mean of normalized indices for each of the three dimensions.
#
# The health dimension is assessed by life expectancy at birth, the education dimension is measured by mean of years of schooling for adults aged 25 years and more and expected years of schooling for children of school entering age. The standard of living dimension is measured by gross national income per capita. The HDI uses the logarithm of income, to reflect the diminishing importance of income with increasing GNI. The scores for the three HDI dimension indices are then aggregated into a composite index using geometric mean. Refer to Technical notes for more details.

# %%
HDI_r = Pivoting(HDI)
HDI_r.drop(columns=['HDI Rank'],inplace=True)
col_to_move = HDI_r.pop('Human Development Index (value)')
HDI_r.insert(3, 'HDI_value', col_to_move)
HDI_r
# Out:
#          CCode    year  Expected Years of Schooling (years)  HDI_value  \
# 0          AFG  1990.0                                2.936      0.284
# 1          AFG  1991.0                                3.228      0.292
# 2          AFG  1992.0                                3.520      0.299
# 3          AFG  1993.0                                3.812      0.307
# 4          AFG  1994.0                                4.104      0.300
# ...        ...     ...                                  ...        ...
# 6825  ZZO.OECD  2015.0                                  NaN      0.894
# 6826  ZZO.OECD  2019.0                                  NaN      0.905
# 6827  ZZO.OECD  2020.0                                  NaN      0.897
# 6828  ZZO.OECD  2021.0                                  NaN      0.899
# 6829  ZZO.OECD  2022.0                               16.600      0.906
#
#       Gross National Income Per Capita (2017 PPP$)  \
# 0                                         3115.670
# 1                                         2817.305
# 2                                         2474.682
# 3                                         1723.020
# 4                                         1202.010
# ...                                            ...
# 6825                                           NaN
# 6826                                           NaN
# 6827                                           NaN
# 6828                                           NaN
# 6829                                     46318.000
#
#       Life Expectancy at Birth (years)  Mean Years of Schooling (years)
# 0                               45.967                            0.872
# 1                               46.663                            0.915
# 2                               47.596                            0.959
# 3                               51.466                            1.002
# 4                               51.495                            1.045
# ...                                ...                              ...
# 6825                               NaN                              NaN
# 6826                               NaN                              NaN
# 6827                               NaN                              NaN
# 6828                               NaN                              NaN
# 6829                            80.100                           12.200
#
# [6830 rows x 7 columns]

# %% [markdown]
# Countries can be divided in 4 categories: Very high human development (>0.8), High human development (0.700-0.799), Medium human development (0.550-0.699), Low human development (<0.550). https://hdr.undp.org/sites/default/files/2023-24_HDR/hdr2023-24_technical_notes.pdf

# %%
bins = [0, 0.55, 0.7, 0.8, 1]
labels = ['L', 'M', 'H', 'VH']

HDI_r['HDI_Category'] = pd.cut(HDI_r['HDI_value'], bins=bins, labels=labels, include_lowest=True)

# %% [markdown]
# #### IHDI

# %% [markdown]
# IHDI explanation: https://hdr.undp.org/inequality-adjusted-human-development-index#/indicies/IHDI
#
# IHDI is based on a distribution-sensitive class of composite indices proposed by Foster, Lopez-Calva and Szekely (2005), which draws on the Atkinson (1970) family of inequality measures. It is computed as a geometric mean of inequality-adjusted dimensional indices. The IHDI accounts for inequalities in HDI dimensions by “discounting” each dimension’s average value according to its level of inequality. The IHDI value equals the HDI value when there is no inequality across people but falls below the HDI value as inequality rises. In this sense, the IHDI measures the level of human development when inequality is accounted for.

# %%
IHDI_r = Pivoting(IHDI)
col_to_move = IHDI_r.pop('Inequality-adjusted Human Development Index (value)')
IHDI_r.insert(3, 'IHDI_value', col_to_move)
IHDI_r
# Out:
#           CCode    year  Coefficient of human inequality  IHDI_value  \
# 0           AFG  2010.0                           35.768       0.287
# 1           AFG  2011.0                           35.453       0.293
# 2           AFG  2012.0                           34.755       0.302
# 3           AFG  2013.0                           34.478       0.309
# 4           AFG  2014.0                           34.322       0.313
# ...         ...     ...                              ...         ...
# 2677  ZZK.WORLD  2022.0                           21.732       0.576
# 2678     ZZL.DC  2022.0                           24.200       0.524
# 2679    ZZM.LDC  2022.0                           32.700       0.363
# 2680   ZZN.SIDS  2022.0                           23.200       0.558
# 2681   ZZO.OECD  2022.0                           11.100       0.803
#
#       Inequality in eduation  Inequality in income  \
# 0                     44.823                28.638
# 1                     44.823                28.638
# 2                     44.823                27.406
# 3                     44.823                27.406
# 4                     44.823                27.406
# ...                      ...                   ...
# 2677                  21.725                30.330
# 2678                  25.000                32.500
# 2679                  36.200                38.600
# 2680                  22.000                32.700
# 2681                   6.700                21.800
#
#       Inequality in life expectancy  Overall loss (%)
# 0                            33.842            36.080
# 1                            32.897            35.886
# 2                            32.036            35.332
# 3                            31.204            34.947
# 4                            30.736            34.792
# ...                             ...               ...
# 2677                         13.141            22.057
# 2678                         14.900               NaN
# 2679                         23.400               NaN
# 2680                         14.900               NaN
# 2681                          4.700               NaN
#
# [2682 rows x 8 columns]

# %% [markdown]
# #### GDP per capita

# %%
GDP_PC = gdp_pc.copy().drop(columns=['Indicator Name','Indicator Code','Unnamed: 68','Country Name'])
GDP_PC.rename(columns={'Country Code':'CCode'},inplace=True)
GDP_PC = GDP_PC.melt(id_vars=['CCode'],var_name='year',value_name='GDP_PC_value')
GDP_PC['year'] = pd.to_datetime(GDP_PC['year'], format='%Y',errors='coerce').dt.year
GDP_PC['logGDP'] = np.log(GDP_PC['GDP_PC_value'])
GDP_PC
# Out:
#       CCode  year  GDP_PC_value    logGDP
# 0       ABW  1960           NaN       NaN
# 1       AFE  1960    186.132432  5.226458
# 2       AFG  1960           NaN       NaN
# 3       AFW  1960    121.938353  4.803516
# 4       AGO  1960           NaN       NaN
# ...     ...   ...           ...       ...
# 17019   XKX  2023   5960.158205  8.692852
# 17020   YEM  2023    477.409029  6.168374
# 17021   ZAF  2023   6022.542542  8.703265
# 17022   ZMB  2023   1330.727806  7.193481
# 17023   ZWE  2023   2156.034004  7.676026
#
# [17024 rows x 4 columns]

# %% [markdown]
# ### Schooling

# %%
SCH_r = Pivoting(SCH) # Pivot the dataframe

# %%
SCH_r.columns
# Out:
# Index(['CCode', 'year', 'Adult illiterate population, 15+ years, % female',
#        'Adult illiterate population, 15+ years, both sexes (number)',
#        'Adult illiterate population, 15+ years, female (number)',
#        'Adult illiterate population, 15+ years, male (number)',
#        'Adult illiterate population, 15+ years, rural, % female',
#        'Adult illiterate population, 15+ years, rural, both sexes (number)',
#        'Adult illiterate population, 15+ years, rural, female (number)',
#        'Adult illiterate population, 15+ years, rural, male (number)',
#        ...
#        'Total net enrolment rate, primary, male (%)',
#        'Total net enrolment rate, upper secondary, adjusted gender parity index (GPIA)',
#        'Total net enrolment rate, upper secondary, both sexes (%)',
#        'Total net enrolment rate, upper secondary, female (%)',
#        'Total net enrolment rate, upper secondary, male (%)',
#        'Total outbound internationally mobile tertiary students studying abroad, all countries, both sexes (UIS estimate) (number)',
#        'Youth illiterate population, 15-24 years, % female',
#        'Youth illiterate population, 15-24 years, both sexes (number)',
#        'Youth illiterate population, 15-24 years, female (number)',
#        'Youth illiterate population, 15-24 years, male (number)'],
#       dtype='object', length=1621)

# %% [markdown]
# ## Merged Datasets

# %% [markdown]
# #### GDP per capita & GII

# %%
GDP_PC_GII = pd.merge(
    GDP_PC, GII_r,
    on=["CCode", "year"], 
    how="inner"
)
GDP_PC_GII.columns.name = None

# %% [markdown]
# #### GDP per capita & GDI

# %%
GDP_PC_GDI = pd.merge(  
    GDP_PC, GDI_r,
    on=["CCode", "year"], 
    how="inner"
)
GDP_PC_GDI.columns.name = None

# %% [markdown]
# #### GDP per capita & HDI

# %%
GDP_PC_HDI = pd.merge(  
    GDP_PC, HDI_r,
    on=["CCode", "year"], 
    how="inner"
)
GDP_PC_HDI.columns.name = None

# %% [markdown]
# #### GDP per capita & IDHI

# %%
GDP_PC_IHDI = pd.merge(  
    GDP_PC, IHDI_r,
    on=["CCode", "year"], 
    how="inner"
)
GDP_PC_IHDI.columns.name = None

# %% [markdown]
# #### Indexes

# %%
gii_r = GII_r[['CCode','year','GII_value','GII_Category']]
gdi_r = GDI_r[['CCode','year','GDI_value','GDI Group']]
hdi_r = HDI_r[['CCode','year','HDI_value','HDI_Category']]
ihdi_r = IHDI_r[['CCode','year','IHDI_value']]

IDX = pd.merge(
    GDP_PC, gii_r,
    on=["CCode", "year"], 
    how="outer"
)
IDX = pd.merge(
    IDX, gdi_r,
    on=["CCode", "year"], 
    how="outer"
)
IDX = pd.merge(
    IDX, hdi_r,
    on=["CCode", "year"], 
    how="outer"
)
IDX = pd.merge(
    IDX, ihdi_r,
    on=["CCode", "year"], 
    how="outer"
)

# %%
IDX = IDX[IDX['year']>=GII_r['year'].min()]
IDX = IDX[IDX['year']<=GII_r['year'].max()]

# %% [markdown]
# # Data visualization

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='GII_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='GDI_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='HDI_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='IHDI_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="HDI_value", x='GII_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="IHDI_value", x='GII_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="HDI_value", x='GDI_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="IHDI_value", x='GDI_value',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='GII_value', hue='HDI_Category',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='GDI_value', hue='HDI_Category',
    facet_kws=dict(sharex=False),
)
plt.show()

# %%
g = sns.relplot(
    data=IDX, kind="scatter",
    y="logGDP", x='HDI_value', hue='GII_Category',
    facet_kws=dict(sharex=False),
)
g.figure.set_size_inches(15, 10)
plt.show()

# %% [markdown]
# # Correlation

# %%
Matrix = IDX[['logGDP', 'GII_value','GDI_value', 'HDI_value', 'IHDI_value']]
Matrix = Matrix.corr(method='pearson').abs()
np.fill_diagonal(Matrix.values, np.nan)
Matrix.style.background_gradient(cmap='coolwarm', axis=None, gmap=Matrix)
# Out:
# <style type="text/css">
# #T_a9a29_row0_col0, #T_a9a29_row1_col1, #T_a9a29_row2_col2, #T_a9a29_row3_col3, #T_a9a29_row4_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a9a29_row0_col1, #T_a9a29_row1_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a9a29_row0_col2, #T_a9a29_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a9a29_row0_col3, #T_a9a29_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a9a29_row0_col4, #T_a9a29_row4_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_a9a29_row1_col2, #T_a9a29_row2_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_a9a29_row1_col3, #T_a9a29_row3_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a9a29_row1_col4, #T_a9a29_row4_col1 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_a9a29_row2_col3, #T_a9a29_row3_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_a9a29_row2_col4, #T_a9a29_row4_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_a9a29_row3_col4, #T_a9a29_row4_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a9a29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9a29_level0_col0" class="col_heading level0 col0" >logGDP</th>
#       <th id="T_a9a29_level0_col1" class="col_heading level0 col1" >GII_value</th>
#       <th id="T_a9a29_level0_col2" class="col_heading level0 col2" >GDI_value</th>
#       <th id="T_a9a29_level0_col3" class="col_heading level0 col3" >HDI_value</th>
#       <th id="T_a9a29_level0_col4" class="col_heading level0 col4" >IHDI_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9a29_level0_row0" class="row_heading level0 row0" >logGDP</th>
#       <td id="T_a9a29_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_a9a29_row0_col1" class="data row0 col1" >0.800393</td>
#       <td id="T_a9a29_row0_col2" class="data row0 col2" >0.581369</td>
#       <td id="T_a9a29_row0_col3" class="data row0 col3" >0.918360</td>
#       <td id="T_a9a29_row0_col4" class="data row0 col4" >0.921443</td>
#     </tr>
#     <tr>
#       <th id="T_a9a29_level0_row1" class="row_heading level0 row1" >GII_value</th>
#       <td id="T_a9a29_row1_col0" class="data row1 col0" >0.800393</td>
#       <td id="T_a9a29_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_a9a29_row1_col2" class="data row1 col2" >0.674845</td>
#       <td id="T_a9a29_row1_col3" class="data row1 col3" >0.878791</td>
#       <td id="T_a9a29_row1_col4" class="data row1 col4" >0.933778</td>
#     </tr>
#     <tr>
#       <th id="T_a9a29_level0_row2" class="row_heading level0 row2" >GDI_value</th>
#       <td id="T_a9a29_row2_col0" class="data row2 col0" >0.581369</td>
#       <td id="T_a9a29_row2_col1" class="data row2 col1" >0.674845</td>
#       <td id="T_a9a29_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_a9a29_row2_col3" class="data row2 col3" >0.673159</td>
#       <td id="T_a9a29_row2_col4" class="data row2 col4" >0.625000</td>
#     </tr>
#     <tr>
#       <th id="T_a9a29_level0_row3" class="row_heading level0 row3" >HDI_value</th>
#       <td id="T_a9a29_row3_col0" class="data row3 col0" >0.918360</td>
#       <td id="T_a9a29_row3_col1" class="data row3 col1" >0.878791</td>
#       <td id="T_a9a29_row3_col2" class="data row3 col2" >0.673159</td>
#       <td id="T_a9a29_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_a9a29_row3_col4" class="data row3 col4" >0.983391</td>
#     </tr>
#     <tr>
#       <th id="T_a9a29_level0_row4" class="row_heading level0 row4" >IHDI_value</th>
#       <td id="T_a9a29_row4_col0" class="data row4 col0" >0.921443</td>
#       <td id="T_a9a29_row4_col1" class="data row4 col1" >0.933778</td>
#       <td id="T_a9a29_row4_col2" class="data row4 col2" >0.625000</td>
#       <td id="T_a9a29_row4_col3" class="data row4 col3" >0.983391</td>
#       <td id="T_a9a29_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Regression

# %%
Panel_GII = PrepareData(GDP_PC_GII,'GII_value') # Prepare the GII data
Panel_GDI = PrepareData(GDP_PC_GDI,'GDI_value') # Prepare the GDI data
Panel_HDI = PrepareData(GDP_PC_HDI,'HDI_value') # Prepare the HDI data
Panel_IHDI = PrepareData(GDP_PC_IHDI,'IHDI_value') # Prepare the IHDI data

# %%
indecies = ['GII_value', 'GDI_value', 'HDI_value', 'IHDI_value']
Panel_IDX = IDX.copy()

for ind in indecies:
    shift = ind.replace('_value', '') + '_shifted'
    Panel_IDX[shift] = Panel_IDX.groupby('CCode')[ind].shift(1) # Shift the values by 1 year

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma GII_{t-1}+\epsilon$

# %%
Regression(Panel_GII, independent_vars = ['GII_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.0068
# Estimator:                   PanelOLS   R-squared (Between):              0.0852
# No. Observations:                4227   R-squared (Within):               0.0778
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.0929
# Time:                        20:02:16   Log-likelihood                   -83.215
# Cov. Estimator:             Clustered
#                                         F-statistic:                      27.775
# Entities:                         165   P-value                           0.0000
# Avg Obs:                       25.618   Distribution:                  F(1,4030)
# Min Obs:                       3.0000
# Max Obs:                       32.000   F-statistic (robust):             1.3239
#                                         P-value                           0.2500
# Time periods:                      32   Distribution:                  F(1,4030)
# Avg Obs:                       132.09
# Min Obs:                       79.000
# Max Obs:                       164.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           8.6499     0.1577     54.862     0.0000      8.3408      8.9590
# GII_shifted    -0.4704     0.4088    -1.1506     0.2500     -1.2719      0.3311
# ===============================================================================
#
# F-test for Poolability: 260.39
# P-value: 0.0000
# Distribution: F(195,4030)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma GDI_{t-1}+\epsilon$

# %%
Regression(Panel_GDI, independent_vars = ['GDI_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.0296
# Estimator:                   PanelOLS   R-squared (Between):              0.1125
# No. Observations:                4516   R-squared (Within):               0.1185
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.1125
# Time:                        20:02:17   Log-likelihood                   -61.740
# Cov. Estimator:             Clustered
#                                         F-statistic:                      131.15
# Entities:                         181   P-value                           0.0000
# Avg Obs:                       24.950   Distribution:                  F(1,4303)
# Min Obs:                       3.0000
# Max Obs:                       32.000   F-statistic (robust):             11.952
#                                         P-value                           0.0006
# Time periods:                      32   Distribution:                  F(1,4303)
# Avg Obs:                       141.12
# Min Obs:                       72.000
# Max Obs:                       180.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           6.4792     0.5837     11.100     0.0000      5.3348      7.6236
# GDI_shifted     2.1623     0.6254     3.4572     0.0006      0.9361      3.3885
# ===============================================================================
#
# F-test for Poolability: 503.23
# P-value: 0.0000
# Distribution: F(211,4303)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma HDI_{t-1}+\epsilon$

# %%
Regression(Panel_HDI, independent_vars = ['HDI_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.2066
# Estimator:                   PanelOLS   R-squared (Between):              0.7905
# No. Observations:                5562   R-squared (Within):               0.6388
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.7747
# Time:                        20:02:17   Log-likelihood                   -210.29
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1390.0
# Entities:                         192   P-value                           0.0000
# Avg Obs:                       28.969   Distribution:                  F(1,5338)
# Min Obs:                       5.0000
# Max Obs:                       32.000   F-statistic (robust):             74.181
#                                         P-value                           0.0000
# Time periods:                      32   Distribution:                  F(1,5338)
# Avg Obs:                       173.81
# Min Obs:                       137.00
# Max Obs:                       191.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           4.0846     0.4869     8.3893     0.0000      3.1301      5.0390
# HDI_shifted     6.2402     0.7245     8.6128     0.0000      4.8198      7.6605
# ===============================================================================
#
# F-test for Poolability: 123.49
# P-value: 0.0000
# Distribution: F(222,5338)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma IHDI_{t-1}+\epsilon$

# %%
Regression(Panel_IHDI, independent_vars = ['IHDI_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.0791
# Estimator:                   PanelOLS   R-squared (Between):              0.6738
# No. Observations:                1783   R-squared (Within):               0.1267
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.6714
# Time:                        20:02:18   Log-likelihood                    1145.9
# Cov. Estimator:             Clustered
#                                         F-statistic:                      137.73
# Entities:                         167   P-value                           0.0000
# Avg Obs:                       10.677   Distribution:                  F(1,1604)
# Min Obs:                       1.0000
# Max Obs:                       12.000   F-statistic (robust):             11.953
#                                         P-value                           0.0006
# Time periods:                      12   Distribution:                  F(1,1604)
# Avg Obs:                       148.58
# Min Obs:                       112.00
# Max Obs:                       163.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            6.5403     0.6070     10.775     0.0000      5.3498      7.7309
# IHDI_shifted     3.6510     1.0560     3.4573     0.0006      1.5797      5.7224
# ================================================================================
#
# F-test for Poolability: 171.27
# P-value: 0.0000
# Distribution: F(177,1604)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma GII_{t-1}+\eta HDI_{t-1}+\epsilon$

# %%
Regression(Panel_IDX, independent_vars = ['GII_shifted', 'HDI_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.2195
# Estimator:                   PanelOLS   R-squared (Between):              0.7935
# No. Observations:                4200   R-squared (Within):               0.6512
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.7745
# Time:                        20:02:18   Log-likelihood                    495.04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      562.67
# Entities:                         165   P-value                           0.0000
# Avg Obs:                       25.455   Distribution:                  F(2,4002)
# Min Obs:                       3.0000
# Max Obs:                       32.000   F-statistic (robust):             34.437
#                                         P-value                           0.0000
# Time periods:                      32   Distribution:                  F(2,4002)
# Avg Obs:                       131.25
# Min Obs:                       74.000
# Max Obs:                       164.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           3.9310     0.5701     6.8946     0.0000      2.8132      5.0488
# GII_shifted     0.1709     0.2738     0.6243     0.5325     -0.3658      0.7076
# HDI_shifted     6.4029     0.7755     8.2569     0.0000      4.8825      7.9232
# ===============================================================================
#
# F-test for Poolability: 121.45
# P-value: 0.0000
# Distribution: F(195,4002)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $\log(GDP_{pc,t})=\alpha+\beta+\gamma GII_{t-1}+\eta IHDI_{t-1}+\epsilon$

# %%
Regression(Panel_IDX, independent_vars = ['GII_shifted', 'IHDI_shifted'], dependent_var = 'logGDP')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 logGDP   R-squared:                        0.0878
# Estimator:                   PanelOLS   R-squared (Between):              0.7087
# No. Observations:                1648   R-squared (Within):               0.1221
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.7028
# Time:                        20:02:19   Log-likelihood                    1063.4
# Cov. Estimator:             Clustered
#                                         F-statistic:                      71.307
# Entities:                         153   P-value                           0.0000
# Avg Obs:                       10.771   Distribution:                  F(2,1482)
# Min Obs:                       1.0000
# Max Obs:                       12.000   F-statistic (robust):             6.0665
#                                         P-value                           0.0024
# Time periods:                      12   Distribution:                  F(2,1482)
# Avg Obs:                       137.33
# Min Obs:                       103.00
# Max Obs:                       151.00
#
#                               Parameter Estimates
# ================================================================================
#               Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# --------------------------------------------------------------------------------
# const            6.6154     0.6375     10.377     0.0000      5.3649      7.8659
# GII_shifted     -0.2967     0.3615    -0.8209     0.4118     -1.0058      0.4123
# IHDI_shifted     3.7230     1.0836     3.4359     0.0006      1.5976      5.8485
# ================================================================================
#
# F-test for Poolability: 171.73
# P-value: 0.0000
# Distribution: F(163,1482)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $HDI_t=\alpha+\beta+\gamma GII_{t-1}+\epsilon$

# %%
Regression(Panel_IDX, independent_vars = ['GII_shifted'], dependent_var = 'HDI_value')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:              HDI_value   R-squared:                        0.0577
# Estimator:                   PanelOLS   R-squared (Between):              0.1951
# No. Observations:                4513   R-squared (Within):               0.2061
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.2101
# Time:                        20:02:20   Log-likelihood                 1.189e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      263.71
# Entities:                         176   P-value                           0.0000
# Avg Obs:                       25.642   Distribution:                  F(1,4305)
# Min Obs:                       3.0000
# Max Obs:                       32.000   F-statistic (robust):             9.0124
#                                         P-value                           0.0027
# Time periods:                      32   Distribution:                  F(1,4305)
# Avg Obs:                       141.03
# Min Obs:                       79.000
# Max Obs:                       176.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           0.7406     0.0133     55.690     0.0000      0.7145      0.7666
# GII_shifted    -0.1018     0.0339    -3.0021     0.0027     -0.1683     -0.0353
# ===============================================================================
#
# F-test for Poolability: 346.81
# P-value: 0.0000
# Distribution: F(206,4305)
#
# Included effects: Entity, Time

# %% [markdown]
# ### $IHDI_t=\alpha+\beta+\gamma GII_{t-1}+\epsilon$

# %%
Regression(Panel_IDX, independent_vars = ['GII_shifted'], dependent_var = 'IHDI_value')
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:             IHDI_value   R-squared:                        0.0159
# Estimator:                   PanelOLS   R-squared (Between):              0.1313
# No. Observations:                1941   R-squared (Within):               0.1261
# Date:                Sun, Apr 27 2025   R-squared (Overall):              0.1322
# Time:                        20:02:20   Log-likelihood                    6075.6
# Cov. Estimator:             Clustered
#                                         F-statistic:                      28.521
# Entities:                         164   P-value                           0.0000
# Avg Obs:                       11.835   Distribution:                  F(1,1764)
# Min Obs:                       2.0000
# Max Obs:                       13.000   F-statistic (robust):             3.6817
#                                         P-value                           0.0552
# Time periods:                      13   Distribution:                  F(1,1764)
# Avg Obs:                       149.31
# Min Obs:                       112.00
# Max Obs:                       163.00
#
#                               Parameter Estimates
# ===============================================================================
#              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# -------------------------------------------------------------------------------
# const           0.6094     0.0138     44.258     0.0000      0.5824      0.6364
# GII_shifted    -0.0730     0.0380    -1.9188     0.0552     -0.1476      0.0016
# ===============================================================================
#
# F-test for Poolability: 419.13
# P-value: 0.0000
# Distribution: F(175,1764)
#
# Included effects: Entity, Time

# %% [markdown]
# # Other visualizations

# %%
df = IDX[IDX['year'] == GII_r['year'].max()].copy()

# %%
fig = px.choropleth(
    df,
    locations="CCode",           # Colonna dei nomi dei paesi
    locationmode="ISO-3",   # Usa i nomi dei paesi
    color="GII_value",                  # Colonna con i valori numerici
    color_continuous_scale="Reds", # Scegli una scala di colori
    title="Gender Inequality Index (GII) - 2022", # Titolo del grafico
)
fig.update_geos(
    showframe=False,
    showcoastlines=True,
    showland=True,
    showocean=True,
    landcolor='darkgray',
    oceancolor="lightblue", 
    projection_type="natural earth"
)

fig.update_layout(
    title={
        'text': "Gender Inequality Index (GII) - 2022",
        'y':0.95,
        'x':0.475,
        'xanchor': 'center',
        'yanchor': 'top',
        'font': dict(size=22)
    },
    margin={"r":0,"t":50,"l":0,"b":0},
    coloraxis_colorbar=dict(
        title="GII",
        ticks="outside",
        ticklen=5,
        tickcolor='darkgray'
    ),
    font=dict(
        family="Helvetica",
        size=14,
        color="black"
    )
)
fig.update_traces(
    marker_line_width=0.5, 
    marker_line_color="black",
    autocolorscale=False,
    colorbar_title="GII"
)



fig.show()
