# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from linearmodels import PanelOLS
from statsmodels.stats.outliers_influence import variance_inflation_factor
import plotly.express as px

sns.set_theme()

# %% [markdown]
# # Functions

# %%
# Definisci una funzione per mappare i paesi alle regioni
def assign_region(country):
    country = HDR_ISO_country[country]
    if country in Asia:
        return 'EAP'
    elif country in Europe_Central_Asia:
        return 'ECA'
    elif country in Weastern_Europe:
        return 'WE'
    elif country in North_America:
        return 'NA'
    elif country in Arab_states:
        return 'AS'
    elif country in Oceania:
        return 'OC'
    elif country in Areas:
        return 'AREA'

# %%
def Pivoting(df): # Function to pivot the dataframe
    df_r = df.pivot(index=['iso3','hdicode','region','year'], columns='indicator_name', values='value').reset_index()
    df_r.reset_index(inplace=True)
    df_r.columns.name = None
    df_r.drop(columns=['index'], inplace=True)
    df_r['year'] = pd.to_datetime(df_r['year'], format='%Y',errors='coerce').dt.year
    return df_r

# %%
def PrepareData(df,ind): # Function to prepare the data for analysis
    Panel = df.copy()
    shift = ind.replace('_value', '') + '_shifted'
    Panel[shift] = Panel.groupby('iso3')[ind].shift(1)
    Panel.dropna(subset = shift ,inplace=True) # Drop rows with NaN values
    return Panel

# %%
def Regression(Panel,independent_vars,dependent_var): # Function to run the regression
    L = ['iso3','year']
    L.extend(independent_vars)
    L.append(dependent_var)
    model_df = Panel[L].copy()
    model_df = model_df.set_index(['iso3', 'year'])
    # Drop rows with NaN values only in the independent and dependent variable columns
    model_df = model_df.dropna(subset=independent_vars + [dependent_var])
    model_df[independent_vars] = model_df[independent_vars].apply(pd.to_numeric, errors='coerce')
    model_df[dependent_var] = model_df[dependent_var].apply(pd.to_numeric, errors='coerce')

    Y = model_df[dependent_var]
    X = model_df[independent_vars]
    X = sm.add_constant(X)

    mod_fe = PanelOLS(Y,X, entity_effects=True, time_effects=True)
    results = mod_fe.fit(cov_type='clustered',cluster_entity=True)

    return results.summary

# %% [markdown]
# # Data loading and preparation

# %% [markdown]
# ## Data Loading

# %%
path = 'Datasets/'

gdp_pc_ppp = pd.read_csv(path + 'GDP per capita, PPP (current international)/WB_WDI_NY_GDP_PCAP_PP_CD.csv') # GDP per capita, PPP (current international $)
hdr = pd.read_csv(path + 'HDR/HDR25_Composite_indices_complete_time_series.csv',encoding='latin1') # Human Development Index
hdr_labels = pd.read_excel(path + 'HDR/HDR25_Composite_indices_metadata.xlsx', sheet_name = 'codebook') # Human Development
schooling = pd.read_csv(path+'UNESCO/OPRI_DATA_NATIONAL.zip', dtype={'INDICATOR_ID': 'object'}, compression='zip')  # Schooling data
schooling_labels = pd.read_csv(path+'UNESCO/OPRI_LABEL.csv') # Schooling labels
gs = pd.read_csv(path + 'GenderStatistics/GS.csv') # Globalization data
# Out:
# /var/folders/pl/qxmk8x1d1m586z4_j013bvqw0000gn/T/ipykernel_3002/247098959.py:6: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   schooling = pd.read_csv(path+'UNESCO/OPRI_DATA_NATIONAL.zip', dtype={'INDICATOR_ID': 'object'}, compression='zip')  # Schooling data

# %% [markdown]
# ## Data preparation

# %%
GS = gs.copy()
GS = GS.drop(columns=['Unnamed: 0'])
GS = GS.rename(columns={'REF_AREA': 'iso3', 'YEAR': 'year'})

# %% [markdown]
# ### HDR

# %%
HDR_ISO_country = {hdr['iso3'][i]:hdr['country'][i] for i in range(len(hdr))}

# %%
hdr_labels.drop(columns=['Time series'], inplace=True)
hdr_labels.dropna(subset=['Short name'], inplace=True)
hdr_labels.rename(columns={'Full name': 'indicator_name', 'Short name': 'indicator'}, inplace=True)

# %%
HDR = hdr.copy()
df_melted = HDR.melt(id_vars=['iso3', 'country', 'hdicode', 'region', 'hdi_rank_2023'], var_name='indicator_year', value_name='value') # Melt the dataframe to long format
df_melted[['indicator', 'year']] = df_melted['indicator_year'].str.extract(r'([a-z0-9_]+)_(\d{4})')
df_final = df_melted[['iso3','hdicode','region','year', 'indicator', 'value']] # Reorder and select final columns
HDR = pd.merge(hdr_labels, df_final, on=['indicator'], how='right') # Merge with labels

# %%
North_America = ['Canada','United States'] 
Oceania = ['Australia','New Zealand'] 
Asia = ['Hong Kong, China (SAR)','Korea (Republic of)','Japan'] 
Europe_Central_Asia = ['Cyprus','Russian Federation','Israel'] 
Weastern_Europe = ['Andorra', 'Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Czechia', 'Denmark', 
                   'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 
                   'Italy', 'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco', 
                   'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'San Marino', 'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland','United Kingdom']
Arab_states = ['Algeria', 'Bahrain', 'Djibouti', 'Egypt', 'Iraq', 'Jordan']
Areas = ['Very high human development', 'High human development',
       'Medium human development', 'Low human development', 'Arab States',
       'East Asia and the Pacific', 'Europe and Central Asia',
       'Latin America and the Caribbean', 'South Asia',
       'Sub-Saharan Africa', 'World']

# %%
region_labels = {
    'ECA': 'Europe & Central Asia',
    'AS':  'Arab States',
    'SSA': 'Sub-Saharan Africa', 
    'LAC': 'Latin America & Caribbean',
    'SA':  'South Asia',
    'EAP': 'East Asia & Pacific',
    'AS':  'Arab States',
    'NA': 'North America',
    'WE': 'Western Europe',
    'OC': 'Oceania'
}

# %%
h = HDR[HDR['region'].isna()].copy()
h.loc[:,'region'] = h.loc[:,'iso3'].apply(assign_region)
HDR = pd.concat([HDR[~HDR['region'].isna()], h], ignore_index=True) # Concatenate the two dataframes
HDR.dropna(subset=['value'], inplace=True) # Drop rows with NaN values in the region column
HDR = HDR[HDR['region'] != 'AREA']

# %%
HDI_indicators = ['hdi', 'le', 'eys', 'mys', 'gnipc']
GDI_indicators = ['gdi_group', 'gdi', 'hdi_f', 'le_f', 'eys_f', 'mys_f', 'gni_pc_f', 'hdi_m', 'le_m', 'eys_m', 'mys_m', 'gni_pc_m']
IHDI_indicators = ['ihdi', 'coef_ineq', 'loss', 'ineq_le', 'ineq_edu', 'ineq_inc']
GII_indicators = ['gii_rank', 'gii', 'mmr', 'abr', 'se_f', 'se_m', 'pr_f', 'pr_m', 'lfpr_f', 'lfpr_m']
PHDI_indicators = ['rankdiff_hdi_phdi', 'phdi', 'diff_hdi_phdi', 'co2_prod', 'mf']
Population_indicator = ['pop_total']

# %%
hdi = HDR[HDR['indicator'].isin(HDI_indicators+Population_indicator)]
gdi = HDR[HDR['indicator'].isin(GDI_indicators+Population_indicator)]
ihdi = HDR[HDR['indicator'].isin(IHDI_indicators+Population_indicator)]
gii = HDR[HDR['indicator'].isin(GII_indicators+Population_indicator)]
phdi = HDR[HDR['indicator'].isin(PHDI_indicators+Population_indicator)]

# %%
HDI = Pivoting(hdi)
GDI = Pivoting(gdi)
IHDI = Pivoting(ihdi)
GII = Pivoting(gii)

# %%
HDR_idx = {'hdi': 'Human Development Index (value)', 'gii': 'Gender Inequality Index (value)', 
           'gdi': 'Gender Development Index (value)', 'ihdi': 'Inequality-adjusted Human Development Index (value)'}

# %% [markdown]
# #### GDP per Capita PPP

# %%
WB_ISO_country = {gdp_pc_ppp['REF_AREA_ID'][i]:gdp_pc_ppp['REF_AREA_NAME'][i] for i in range(len(gdp_pc_ppp))}

# %%
GDP = gdp_pc_ppp.copy()
GDP = GDP[['REF_AREA_ID','TIME_PERIOD','OBS_VALUE']]
GDP.rename(columns={'REF_AREA_ID':'iso3','TIME_PERIOD':'year','OBS_VALUE':'GDP'},inplace=True)
GDP['year'] = pd.to_datetime(GDP['year'], format='%Y',errors='coerce').dt.year
GDP['logGDP'] = np.log(GDP['GDP'])

# %% [markdown]
# #### Schooling

# %%
SCH = schooling.copy()
SCH['INDICATOR_ID'] = SCH['INDICATOR_ID'].astype(str)
SCH = SCH[SCH['INDICATOR_ID'].str.contains('NART', na=False)] 
SCH = SCH.drop(columns=['MAGNITUDE','QUALIFIER'])
SCH = pd.merge(schooling_labels,SCH,how='left',on='INDICATOR_ID') # Merge the labels with the schooling data
SCH['YEAR'] = pd.to_datetime(SCH['YEAR'], format='%Y',errors='coerce').dt.year

# %%
Primary = SCH[SCH['INDICATOR_ID'].str.contains('NART.1', na=False)] # Filter for primary education
Secondary = SCH[SCH['INDICATOR_ID'].str.contains('NART.2', na=False)] # Filter for secondary education
Tertiary = SCH[SCH['INDICATOR_ID'].str.contains('NART.3', na=False)] # Filter for tertiary education

# %%
P = Primary.pivot(index=['COUNTRY_ID','YEAR'], columns='INDICATOR_LABEL_EN', values='VALUE').reset_index()
S = Secondary.pivot(index=['COUNTRY_ID','YEAR'], columns='INDICATOR_LABEL_EN', values='VALUE').reset_index()
T = Tertiary.pivot(index=['COUNTRY_ID','YEAR'], columns='INDICATOR_LABEL_EN', values='VALUE').reset_index()

# %%
P.rename(columns={'COUNTRY_ID':'iso3','YEAR':'year'}, inplace=True)
S.rename(columns={'COUNTRY_ID':'iso3','YEAR':'year'}, inplace=True)
T.rename(columns={'COUNTRY_ID':'iso3','YEAR':'year'}, inplace=True)

# %% [markdown]
# # Simple regressions

# %%
Results = {}

# %%
# GDP and GII
GDP_GII = pd.merge(GDP, GII, on=["iso3", "year"],how="inner")
GDP_GII.columns.name = None

Panel_GII = PrepareData(GDP_GII,HDR_idx['gii']) # Prepare the GII data
Panel_GII = Panel_GII[~Panel_GII['iso3'].isin(['KWT', 'ARE', 'SAU', 'QAT'])] # Filter the GII data to include only countries present in the GDP data
Results['GDP/GII'] = Regression(Panel_GII, independent_vars = [HDR_idx['gii']+'_shifted'], dependent_var = 'logGDP')

# %%
# GDP and GII+schooling
GDP_GII_Schooling = pd.merge(GDP_GII, T, on=["iso3", "year"],how="inner")
GDP_GII_Schooling.columns.name = None


Panel_GII_Schooling = PrepareData(GDP_GII_Schooling,HDR_idx['gii']) # Prepare the GII data
Panel_GII_Schooling['Total net attendance rate, upper secondary, female (%)'] = Panel_GII_Schooling['Total net attendance rate, upper secondary, female (%)']/100
Results['GDP/GII+Schooling'] = Regression(Panel_GII_Schooling, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)'], dependent_var = 'logGDP')

# %%
# GDP and GII - It can't be used with PanelOLS
GDP_GII_Schooling_GS = pd.merge(GDP_GII_Schooling, GS, on=["iso3", "year"],how="inner")
GDP_GII_Schooling_GS.columns.name = None

Panel_GII_Schooling_GS = PrepareData(GDP_GII_Schooling_GS,HDR_idx['gii']) # Prepare the GII data
vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)'] + GS.columns.to_list()[2:]
# Regression(Panel_GII_Schooling_GS, independent_vars = vars, dependent_var = 'logGDP') They do not change
del vars

# %%
# GDP and GII + HDI_female
GDP_GII_Schooling_GDI = pd.merge(GDP_GII_Schooling, GDI, on=["iso3", "year", "hdicode", "region"],how="inner")
GDP_GII_Schooling_GDI.columns.name = None

Panel_GII_Schooling_GDI = PrepareData(GDP_GII_Schooling_GDI,HDR_idx['gii']) # Prepare the GII data
Panel_GII_Schooling_GDI = PrepareData(Panel_GII_Schooling_GDI,'HDI female (value)') # Prepare the GII data
Results['GDP/GII+Schooling+HDI_female'] = Regression(Panel_GII_Schooling_GDI, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)','HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
# GDP and GII + HDI_female
GDP_GII_GDI = pd.merge(GDP_GII, GDI, on=["iso3", "year", "hdicode", "region"],how="inner")
GDP_GII_GDI.columns.name = None

Panel_GII_GDI = PrepareData(GDP_GII_GDI,HDR_idx['gii']) # Prepare the GII data
Panel_GII_GDI = PrepareData(Panel_GII_GDI,'HDI female (value)') # Prepare the GII data
Results['GDP/GII+HDI_female'] = Regression(Panel_GII_GDI, independent_vars = [HDR_idx['gii']+'_shifted','HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
# GDP and HDI_female
GDP_GDI = pd.merge(GDP, GDI, on=["iso3", "year"],how="inner")
GDP_GDI.columns.name = None

Panel_GDI = PrepareData(GDP_GDI,'HDI female (value)') # Prepare the GII data
Results['GDP/HDI_Female'] = Regression(Panel_GDI, independent_vars = ['HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
# GDP and GII
GDP_HDI = pd.merge(GDP, HDI, on=["iso3", "year"],how="inner")
GDP_HDI.columns.name = None

Panel_HDI = PrepareData(GDP_HDI,HDR_idx['hdi']) # Prepare the GII data
Results['GDP/HDI'] = Regression(Panel_HDI, independent_vars = [HDR_idx['hdi']+'_shifted'], dependent_var = 'logGDP')

# %%
# HDI and GII
HDI_GII = pd.merge(HDI, GII, on=["iso3", "year","hdicode","region"],how="inner")
HDI_GII.columns.name = None

Panel_HDI_GII = PrepareData(HDI_GII,HDR_idx['gii']) # Prepare the GII data
Results['HDI/GII'] = Regression(Panel_HDI_GII, independent_vars = [HDR_idx['gii']+'_shifted'], dependent_var = HDR_idx['hdi'])

# %%
# GDI and GII
GDI_GII = pd.merge(GDI, GII, on=["iso3", "year"],how="inner")
GDI_GII.columns.name = None

Panel_GDI_GII = PrepareData(GDI_GII,HDR_idx['gii']) # Prepare the GII data
Results['HDI_female/GII'] = Regression(Panel_GDI_GII, independent_vars = [HDR_idx['gii']+'_shifted'], dependent_var = 'HDI female (value)')

# %%
Panel1 = GDP_GII[['iso3', 'year', 'logGDP','hdicode','region',
       'Adolescent Birth Rate (births per 1,000 women ages 15-19)',
       'Labour force participation rate, female (% ages 15 and older)',
       'Maternal Mortality Ratio (deaths per 100,000 live births)',
       'Population with at least some secondary education, female (% ages 25 and older)',
       'Share of seats in parliament, female (% held by women)']].copy()

Panel1.loc[:,'Adolescent Birth Rate (% women ages 15-19)'] = Panel1.loc[:,'Adolescent Birth Rate (births per 1,000 women ages 15-19)']/1000
Panel1.loc[:,'Maternal Mortality Ratio (%)'] = Panel1.loc[:,'Maternal Mortality Ratio (deaths per 100,000 live births)']/100000

Panel1 = Panel1.drop(columns=['Adolescent Birth Rate (births per 1,000 women ages 15-19)','Maternal Mortality Ratio (deaths per 100,000 live births)'])
Panel1 = Panel1.dropna() # Drop rows with NaN values

# %%
vars = Panel1.columns.to_list()[5:]
Results['GDP/GII_components'] = Regression(Panel1, independent_vars = vars, dependent_var = 'logGDP')

# %%
del vars

# %% [markdown]
# # Splitting in HDI level

# %%
HDI_levels = HDI['hdicode'].unique()
HDI_levels = [x for x in HDI_levels if x is not np.nan]
HDI_levels.remove('Other Countries or Territories')

# %%
for i in HDI_levels:
    Panel_GII_1 = GDP_GII[GDP_GII['hdicode'] == i].copy()
    Panel_GII_1 = PrepareData(Panel_GII_1,HDR_idx['gii']) # Prepare the GII data
    Results['GDP/GII:HDI_'+str(i)] = Regression(Panel_GII_1, independent_vars = [HDR_idx['gii']+'_shifted'], dependent_var = 'logGDP')

# %%
for i in HDI_levels:
    Panel_GII_Schooling_1 = Panel_GII_Schooling[Panel_GII_Schooling['hdicode'] == i].copy()
    Results['GDP/GII+Schooling:HDI_'+str(i)] = Regression(Panel_GII_Schooling_1, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)'], dependent_var = 'logGDP')

# %%
for i in HDI_levels:
    Panel_GII_Schooling_GDI_1 = Panel_GII_Schooling_GDI[Panel_GII_Schooling_GDI['hdicode'] == i].copy()
    Results['GDP/GII+Schooling+HDI_Female:HDI_'+str(i)] = Regression(Panel_GII_Schooling_GDI_1, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)','HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
for i in HDI_levels:
    Panel_GII_GDI_1 = Panel_GII_GDI[Panel_GII_GDI['hdicode'] == i].copy()
    Results['GDP/GII+HDI_Female:HDI_'+str(i)] = Regression(Panel_GII_GDI_1, independent_vars = [HDR_idx['gii']+'_shifted','HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
for i in HDI_levels:
    Panel_GDI_1 = Panel_GDI[Panel_GDI['hdicode'] == i].copy()
    Results['GDP/HDI_Female:HDI_'+str(i)] = Regression(Panel_GDI_1, independent_vars = ['HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
for i in HDI_levels:
    Panel1_1 = Panel1[Panel1['hdicode'] == i].copy()
    vars = Panel1.columns.to_list()[5:]
    Results['GDP/GII_components:HDI_'+str(i)] = Regression(Panel1_1, independent_vars = vars, dependent_var = 'logGDP')

# %%
vars = Panel1.columns.to_list()[5:]
vars.remove('Share of seats in parliament, female (% held by women)')
vars.remove('Population with at least some secondary education, female (% ages 25 and older)')
Panel1_1 = Panel1[Panel1['hdicode'] == 'Medium'].copy()
Results['GDP/Labour force participation rate, female (% ages 15 and older)+Adolescent Birth Rate (% women ages 15-19)+Maternal Mortality Ratio (%):HDI_medium'] = Regression(Panel1_1, independent_vars = vars, dependent_var = 'logGDP')

# %%
del vars

# %% [markdown]
# # Splitting in regions

# %%
Regions = GDP_GII['region'].unique()

# %%
for i in Regions:
    Panel_GII_2 = GDP_GII[GDP_GII['region'] == i].copy()
    Panel_GII_2 = PrepareData(Panel_GII_2,HDR_idx['gii']) # Prepare the GII data
    Results['GDP/GII:Region_'+str(i)] = Regression(Panel_GII_2, independent_vars = [HDR_idx['gii']+'_shifted'], dependent_var = 'logGDP')

# %%
for i in ['SSA', 'LAC', 'SA']:
    Panel_GII_Schooling_2 = Panel_GII_Schooling[Panel_GII_Schooling['region'] == i].copy()
    Results['GDP/GII+Schooling:Region_'+str(i)] = Regression(Panel_GII_Schooling_2, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)'], dependent_var = 'logGDP')

# %%
for i in ['SSA', 'LAC']:
    Panel_GII_Schooling_GDI_2 = Panel_GII_Schooling_GDI[Panel_GII_Schooling_GDI['region'] == i].copy()
    Results['GDP/GII+Schooling+HDI_Female:Region_'+str(i)] = Regression(Panel_GII_Schooling_GDI_2, independent_vars = [HDR_idx['gii']+'_shifted','Total net attendance rate, upper secondary, female (%)','HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
for i in Regions:
    Panel_GII_GDI_2 = Panel_GII_GDI[Panel_GII_GDI['region'] == i].copy()
    Results['GDP/GII+HDI_Female:Region_'+str(i)] = Regression(Panel_GII_GDI_2, independent_vars = [HDR_idx['gii'],'HDI female (value)'+'_shifted'], dependent_var = 'logGDP')

# %%
for i in Regions:
    Panel_GDI_2 = Panel_GDI[Panel_GDI['region'] == i].copy()
    Results['GDP/HDI_Female:Region_'+str(i)] = Regression(Panel_GDI_2, independent_vars = ['HDI female (value)'], dependent_var = 'logGDP')

# %%
for i in Regions:
    Panel1_2 = Panel1[Panel1['region'] == i].copy()
    vars = Panel1.columns.to_list()[5:]
    # Results['GDP/GII_components:Region_'+str(i)] = Regression(Panel1_2, independent_vars = vars, dependent_var = 'logGDP')

# %%
del vars

# %%
Results
# Out:
# {'GDP/GII': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0458
#  Estimator:                   PanelOLS   R-squared (Between):              0.2618
#  No. Observations:                4264   R-squared (Within):               0.2220
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.2699
#  Time:                        14:58:52   Log-likelihood                    1855.8
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      195.15
#  Entities:                         166   P-value                           0.0000
#  Avg Obs:                       25.687   Distribution:                  F(1,4065)
#  Min Obs:                       1.0000
#  Max Obs:                       33.000   F-statistic (robust):             10.783
#                                          P-value                           0.0010
#  Time periods:                      33   Distribution:                  F(1,4065)
#  Avg Obs:                       129.21
#  Min Obs:                       79.000
#  Max Obs:                       164.00
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       9.5824     0.1214     78.936     0.0000      9.3444      9.8204
#  Gender Inequality Index (value)_shifted    -1.0418     0.3173    -3.2837     0.0010     -1.6638     -0.4198
#  ===========================================================================================================
#
#  F-test for Poolability: 298.33
#  P-value: 0.0000
#  Distribution: F(197,4065)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0070
#  Estimator:                   PanelOLS   R-squared (Between):              0.0288
#  No. Observations:                 454   R-squared (Within):               0.0769
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.0832
#  Time:                        14:58:52   Log-likelihood                    481.23
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      1.2204
#  Entities:                          84   P-value                           0.2964
#  Avg Obs:                       5.4048   Distribution:                   F(2,346)
#  Min Obs:                       1.0000
#  Max Obs:                       23.000   F-statistic (robust):             0.4222
#                                          P-value                           0.6560
#  Time periods:                      23   Distribution:                   F(2,346)
#  Avg Obs:                       19.739
#  Min Obs:                       6.0000
#  Max Obs:                       33.000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      9.0324     0.1896     47.645     0.0000      8.6595      9.4053
#  Gender Inequality Index (value)_shifted                   -0.2285     0.3440    -0.6642     0.5070     -0.9052      0.4482
#  Total net attendance rate, upper secondary, female (%)     0.1134     0.1633     0.6946     0.4878     -0.2078      0.4346
#  ==========================================================================================================================
#
#  F-test for Poolability: 103.91
#  P-value: 0.0000
#  Distribution: F(105,346)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling+HDI_female': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.1448
#  Estimator:                   PanelOLS   R-squared (Between):              0.5654
#  No. Observations:                 365   R-squared (Within):               0.4456
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.6262
#  Time:                        14:58:52   Log-likelihood                    446.47
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      15.356
#  Entities:                          69   P-value                           0.0000
#  Avg Obs:                       5.2899   Distribution:                   F(3,272)
#  Min Obs:                       1.0000
#  Max Obs:                       22.000   F-statistic (robust):             2.8905
#                                          P-value                           0.0359
#  Time periods:                      22   Distribution:                   F(3,272)
#  Avg Obs:                       16.591
#  Min Obs:                       6.0000
#  Max Obs:                       27.000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      6.8853     0.9036     7.6200     0.0000      5.1064      8.6642
#  Gender Inequality Index (value)_shifted                    0.3622     0.6581     0.5503     0.5826     -0.9334      1.6578
#  Total net attendance rate, upper secondary, female (%)     0.0032     0.0018     1.7597     0.0796     -0.0004      0.0067
#  HDI female (value)_shifted                                 2.7262     0.9765     2.7918     0.0056      0.8037      4.6486
#  ==========================================================================================================================
#
#  F-test for Poolability: 45.084
#  P-value: 0.0000
#  Distribution: F(89,272)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+HDI_female': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.1939
#  Estimator:                   PanelOLS   R-squared (Between):              0.6487
#  No. Observations:                4008   R-squared (Within):               0.5447
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.6459
#  Time:                        14:58:53   Log-likelihood                    1999.8
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      457.64
#  Entities:                         169   P-value                           0.0000
#  Avg Obs:                       23.716   Distribution:                  F(2,3806)
#  Min Obs:                       1.0000
#  Max Obs:                       32.000   F-statistic (robust):             37.716
#                                          P-value                           0.0000
#  Time periods:                      32   Distribution:                  F(2,3806)
#  Avg Obs:                       125.25
#  Min Obs:                       63.000
#  Max Obs:                       166.00
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       6.3386     0.3572     17.743     0.0000      5.6382      7.0391
#  Gender Inequality Index (value)_shifted     0.6542     0.2770     2.3615     0.0183      0.1111      1.1974
#  HDI female (value)_shifted                  3.9052     0.4499     8.6803     0.0000      3.0231      4.7872
#  ===========================================================================================================
#
#  F-test for Poolability: 141.38
#  P-value: 0.0000
#  Distribution: F(199,3806)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.1702
#  Estimator:                   PanelOLS   R-squared (Between):              0.6970
#  No. Observations:                4642   R-squared (Within):               0.6139
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.6843
#  Time:                        14:58:54   Log-likelihood                    1839.2
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      908.19
#  Entities:                         182   P-value                           0.0000
#  Avg Obs:                       25.505   Distribution:                  F(1,4427)
#  Min Obs:                       1.0000
#  Max Obs:                       33.000   F-statistic (robust):             41.647
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                  F(1,4427)
#  Avg Obs:                       140.67
#  Min Obs:                       74.000
#  Max Obs:                       179.00
#
#                                       Parameter Estimates
#  ==============================================================================================
#                              Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  ----------------------------------------------------------------------------------------------
#  const                          6.6662     0.3984     16.734     0.0000      5.8853      7.4472
#  HDI female (value)_shifted     3.7542     0.5817     6.4534     0.0000      2.6137      4.8946
#  ==============================================================================================
#
#  F-test for Poolability: 161.51
#  P-value: 0.0000
#  Distribution: F(213,4427)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.2160
#  Estimator:                   PanelOLS   R-squared (Between):              0.7710
#  No. Observations:                5588   R-squared (Within):               0.6694
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.7590
#  Time:                        14:58:54   Log-likelihood                    1888.6
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      1477.4
#  Entities:                         191   P-value                           0.0000
#  Avg Obs:                       29.257   Distribution:                  F(1,5364)
#  Min Obs:                       1.0000
#  Max Obs:                       33.000   F-statistic (robust):             61.630
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                  F(1,5364)
#  Avg Obs:                       169.33
#  Min Obs:                       137.00
#  Max Obs:                       187.00
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       5.9408     0.3987     14.902     0.0000      5.1592      6.7223
#  Human Development Index (value)_shifted     4.5826     0.5837     7.8505     0.0000      3.4382      5.7269
#  ===========================================================================================================
#
#  F-test for Poolability: 148.35
#  P-value: 0.0000
#  Distribution: F(222,5364)
#
#  Included effects: Entity, Time
#  """,
#  'HDI/GII': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                                   PanelOLS Estimation Summary
#  =============================================================================================
#  Dep. Variable:     Human Development Index (value)   R-squared:                        0.0546
#  Estimator:                                PanelOLS   R-squared (Between):              0.1745
#  No. Observations:                             4383   R-squared (Within):               0.1943
#  Date:                             Tue, May 13 2025   R-squared (Overall):              0.1948
#  Time:                                     14:58:55   Log-likelihood                 1.149e+04
#  Cov. Estimator:                          Clustered
#                                                       F-statistic:                      241.17
#  Entities:                                      172   P-value                           0.0000
#  Avg Obs:                                    25.483   Distribution:                  F(1,4178)
#  Min Obs:                                    1.0000
#  Max Obs:                                    33.000   F-statistic (robust):             8.9202
#                                                       P-value                           0.0028
#  Time periods:                                   33   Distribution:                  F(1,4178)
#  Avg Obs:                                    132.82
#  Min Obs:                                    77.000
#  Max Obs:                                    172.00
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       0.7493     0.0119     62.840     0.0000      0.7260      0.7727
#  Gender Inequality Index (value)_shifted    -0.0929     0.0311    -2.9867     0.0028     -0.1539     -0.0319
#  ===========================================================================================================
#
#  F-test for Poolability: 352.54
#  P-value: 0.0000
#  Distribution: F(203,4178)
#
#  Included effects: Entity, Time
#  """,
#  'HDI_female/GII': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:     HDI female (value)   R-squared:                        0.0629
#  Estimator:                   PanelOLS   R-squared (Between):              0.1940
#  No. Observations:                4249   R-squared (Within):               0.2035
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.2141
#  Time:                        14:58:55   Log-likelihood                 1.073e+04
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      271.42
#  Entities:                         172   P-value                           0.0000
#  Avg Obs:                       24.703   Distribution:                  F(1,4044)
#  Min Obs:                       1.0000
#  Max Obs:                       33.000   F-statistic (robust):             7.6859
#                                          P-value                           0.0056
#  Time periods:                      33   Distribution:                  F(1,4044)
#  Avg Obs:                       128.76
#  Min Obs:                       64.000
#  Max Obs:                       172.00
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       0.7350     0.0151     48.631     0.0000      0.7054      0.7646
#  Gender Inequality Index (value)_shifted    -0.1105     0.0399    -2.7723     0.0056     -0.1887     -0.0324
#  ===========================================================================================================
#
#  F-test for Poolability: 309.71
#  P-value: 0.0000
#  Distribution: F(203,4044)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII_components': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0312
#  Estimator:                   PanelOLS   R-squared (Between):              0.0517
#  No. Observations:                4527   R-squared (Within):              -0.0063
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.0452
#  Time:                        14:58:55   Log-likelihood                    1592.4
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      27.834
#  Entities:                         170   P-value                           0.0000
#  Avg Obs:                       26.629   Distribution:                  F(5,4319)
#  Min Obs:                       2.0000
#  Max Obs:                       34.000   F-statistic (robust):             1.8374
#                                          P-value                           0.1021
#  Time periods:                      34   Distribution:                  F(5,4319)
#  Avg Obs:                       133.15
#  Min Obs:                       79.000
#  Max Obs:                       169.00
#
#                                                                  Parameter Estimates
#  ===================================================================================================================================================
#                                                                                   Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  ---------------------------------------------------------------------------------------------------------------------------------------------------
#  const                                                                               9.3523     0.1354     69.085     0.0000      9.0869      9.6177
#  Labour force participation rate, female (% ages 15 and older)                      -0.0019     0.0015    -1.2259     0.2203     -0.0049      0.0011
#  Population with at least some secondary education, female (% ages 25 and older)    -0.0004     0.0018    -0.2275     0.8200     -0.0039      0.0031
#  Share of seats in parliament, female (% held by women)                             -0.0007     0.0024    -0.2934     0.7692     -0.0053      0.0039
#  Adolescent Birth Rate (% women ages 15-19)                                          0.6870     1.3390     0.5131     0.6079     -1.9381      3.3121
#  Maternal Mortality Ratio (%)                                                       -36.982     14.260    -2.5933     0.0095     -64.939     -9.0241
#  ===================================================================================================================================================
#
#  F-test for Poolability: 287.04
#  P-value: 0.0000
#  Distribution: F(202,4319)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII:HDI_Low': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0138
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0146
#  No. Observations:                 390   R-squared (Within):               0.1332
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.0076
#  Time:                        14:58:56   Log-likelihood                    235.55
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      4.6762
#  Entities:                          22   P-value                           0.0313
#  Avg Obs:                       17.727   Distribution:                   F(1,335)
#  Min Obs:                       1.0000
#  Max Obs:                       33.000   F-statistic (robust):             0.3160
#                                          P-value                           0.5744
#  Time periods:                      33   Distribution:                   F(1,335)
#  Avg Obs:                       11.818
#  Min Obs:                       3.0000
#  Max Obs:                       22.000
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       7.8261     0.6749     11.595     0.0000      6.4985      9.1538
#  Gender Inequality Index (value)_shifted    -0.6078     1.0812    -0.5621     0.5744     -2.7347      1.5191
#  ===========================================================================================================
#
#  F-test for Poolability: 123.30
#  P-value: 0.0000
#  Distribution: F(53,335)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII:HDI_Medium': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.1351
#  Estimator:                   PanelOLS   R-squared (Between):              0.0458
#  No. Observations:                 846   R-squared (Within):               0.3294
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.1165
#  Time:                        14:58:56   Log-likelihood                    438.24
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      121.03
#  Entities:                          38   P-value                           0.0000
#  Avg Obs:                       22.263   Distribution:                   F(1,775)
#  Min Obs:                       5.0000
#  Max Obs:                       33.000   F-statistic (robust):             14.805
#                                          P-value                           0.0001
#  Time periods:                      33   Distribution:                   F(1,775)
#  Avg Obs:                       25.636
#  Min Obs:                       7.0000
#  Max Obs:                       38.000
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       9.0917     0.2513     36.185     0.0000      8.5985      9.5849
#  Gender Inequality Index (value)_shifted    -1.7171     0.4462    -3.8478     0.0001     -2.5931     -0.8411
#  ===========================================================================================================
#
#  F-test for Poolability: 183.57
#  P-value: 0.0000
#  Distribution: F(69,775)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII:HDI_Very High': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0241
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0509
#  No. Observations:                1996   R-squared (Within):              -0.1238
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.0993
#  Time:                        14:58:56   Log-likelihood                    650.57
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      46.746
#  Entities:                          68   P-value                           0.0000
#  Avg Obs:                       29.353   Distribution:                  F(1,1895)
#  Min Obs:                       2.0000
#  Max Obs:                       33.000   F-statistic (robust):             1.2349
#                                          P-value                           0.2666
#  Time periods:                      33   Distribution:                  F(1,1895)
#  Avg Obs:                       60.485
#  Min Obs:                       49.000
#  Max Obs:                       68.000
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       10.022     0.1008     99.442     0.0000      9.8240      10.219
#  Gender Inequality Index (value)_shifted     0.5000     0.4499     1.1113     0.2666     -0.3824      1.3823
#  ===========================================================================================================
#
#  F-test for Poolability: 230.47
#  P-value: 0.0000
#  Distribution: F(99,1895)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII:HDI_High': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0011
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0234
#  No. Observations:                1125   R-squared (Within):              -0.0347
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.0218
#  Time:                        14:58:56   Log-likelihood                    404.39
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      1.1892
#  Entities:                          42   P-value                           0.2757
#  Avg Obs:                       26.786   Distribution:                  F(1,1050)
#  Min Obs:                       4.0000
#  Max Obs:                       33.000   F-statistic (robust):             0.1238
#                                          P-value                           0.7251
#  Time periods:                      33   Distribution:                  F(1,1050)
#  Avg Obs:                       34.091
#  Min Obs:                       20.000
#  Max Obs:                       41.000
#
#                                              Parameter Estimates
#  ===========================================================================================================
#                                           Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  -----------------------------------------------------------------------------------------------------------
#  const                                       9.0003     0.1876     47.974     0.0000      8.6322      9.3684
#  Gender Inequality Index (value)_shifted     0.1469     0.4177     0.3518     0.7251     -0.6726      0.9665
#  ===========================================================================================================
#
#  F-test for Poolability: 120.64
#  P-value: 0.0000
#  Distribution: F(73,1050)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling:HDI_Low': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0186
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0317
#  No. Observations:                  51   R-squared (Within):              -0.0120
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.0106
#  Time:                        14:58:57   Log-likelihood                    67.327
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      0.1801
#  Entities:                          15   P-value                           0.8366
#  Avg Obs:                       3.4000   Distribution:                    F(2,19)
#  Min Obs:                       2.0000
#  Max Obs:                       7.0000   F-statistic (robust):             0.1090
#                                          P-value                           0.8973
#  Time periods:                      16   Distribution:                    F(2,19)
#  Avg Obs:                       3.1875
#  Min Obs:                       1.0000
#  Max Obs:                       7.0000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      7.8650     0.8668     9.0734     0.0000      6.0507      9.6793
#  Gender Inequality Index (value)_shifted                   -0.2966     1.1874    -0.2498     0.8054     -2.7819      2.1887
#  Total net attendance rate, upper secondary, female (%)    -0.2293     0.4911    -0.4669     0.6459     -1.2572      0.7986
#  ==========================================================================================================================
#
#  F-test for Poolability: 37.981
#  P-value: 0.0000
#  Distribution: F(29,19)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling:HDI_Medium': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.2775
#  Estimator:                   PanelOLS   R-squared (Between):             -0.1836
#  No. Observations:                 110   R-squared (Within):               0.4673
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.1667
#  Time:                        14:58:57   Log-likelihood                    158.73
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      11.331
#  Entities:                          27   P-value                           0.0001
#  Avg Obs:                       4.0741   Distribution:                    F(2,59)
#  Min Obs:                       1.0000
#  Max Obs:                       21.000   F-statistic (robust):             4.5340
#                                          P-value                           0.0147
#  Time periods:                      23   Distribution:                    F(2,59)
#  Avg Obs:                       4.7826
#  Min Obs:                       1.0000
#  Max Obs:                       12.000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      9.6205     0.4365     22.040     0.0000      8.7470      10.494
#  Gender Inequality Index (value)_shifted                   -2.5070     0.8365    -2.9968     0.0040     -4.1809     -0.8331
#  Total net attendance rate, upper secondary, female (%)     0.1737     0.1979     0.8778     0.3836     -0.2223      0.5698
#  ==========================================================================================================================
#
#  F-test for Poolability: 75.666
#  P-value: 0.0000
#  Distribution: F(48,59)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling:HDI_Very High': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.2048
#  Estimator:                   PanelOLS   R-squared (Between):             -0.6106
#  No. Observations:                  84   R-squared (Within):              -0.6373
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.6277
#  Time:                        14:58:57   Log-likelihood                    108.96
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      6.0526
#  Entities:                          13   P-value                           0.0046
#  Avg Obs:                       6.4615   Distribution:                    F(2,47)
#  Min Obs:                       1.0000
#  Max Obs:                       21.000   F-statistic (robust):             4.3193
#                                          P-value                           0.0190
#  Time periods:                      23   Distribution:                    F(2,47)
#  Avg Obs:                       3.6522
#  Min Obs:                       1.0000
#  Max Obs:                       6.0000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      9.8067     0.6356     15.430     0.0000      8.5281      11.085
#  Gender Inequality Index (value)_shifted                    1.9876     0.7869     2.5257     0.0150      0.4045      3.5707
#  Total net attendance rate, upper secondary, female (%)    -0.5746     0.6050    -0.9497     0.3471     -1.7917      0.6426
#  ==========================================================================================================================
#
#  F-test for Poolability: 43.478
#  P-value: 0.0000
#  Distribution: F(34,47)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling:HDI_High': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0040
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0062
#  No. Observations:                 209   R-squared (Within):               0.0193
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.0150
#  Time:                        14:58:57   Log-likelihood                    260.56
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      0.3101
#  Entities:                          29   P-value                           0.7338
#  Avg Obs:                       7.2069   Distribution:                   F(2,156)
#  Min Obs:                       1.0000
#  Max Obs:                       23.000   F-statistic (robust):             0.2254
#                                          P-value                           0.7984
#  Time periods:                      23   Distribution:                   F(2,156)
#  Avg Obs:                       9.0870
#  Min Obs:                       4.0000
#  Max Obs:                       14.000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      9.4373     0.2305     40.950     0.0000      8.9820      9.8925
#  Gender Inequality Index (value)_shifted                   -0.1675     0.3521    -0.4758     0.6349     -0.8630      0.5279
#  Total net attendance rate, upper secondary, female (%)    -0.0606     0.3131    -0.1934     0.8469     -0.6791      0.5580
#  ==========================================================================================================================
#
#  F-test for Poolability: 84.942
#  P-value: 0.0000
#  Distribution: F(50,156)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/GII+Schooling+HDI_Female:HDI_Low': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.2862
#  Estimator:                   PanelOLS   R-squared (Between):             -0.1928
#  No. Observations:                  36   R-squared (Within):               0.1220
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.0690
#  Time:                        14:58:57   Log-likelihood                    84.279
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      0.8020
#  Entities:                          15   P-value                           0.5366
#  Avg Obs:                       2.4000   Distribution:                     F(3,6)
#  Min Obs:                       1.0000
#  Max Obs:                       6.0000   F-statistic (robust):             0.4469
#                                          P-value                           0.7285
#  Time periods:                      13   Distribution:                     F(3,6)
#  Avg Obs:                       2.7692
#  Min Obs:                       1.0000
#  Max Obs:                       7.0000
#
#                                                     Parameter Estimates
#  ==========================================================================================================================
#                                                          Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------------------------------------------
#  const                                                      8.2330     2.0370     4.0418     0.0068      3.2487      13.217
#  Gender Inequality Index (value)_shifted                   -0.8359     1.9134    -0.4369     0.6775     -5.5179      3.8461
#  Total net attendance rate, upper secondary, female (%)     0.0047     0.0072     0.6558     0.5363     -0.0129      0.0224
# ...
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      759.41
#  Entities:                          31   P-value                           0.0000
#  Avg Obs:                       31.806   Distribution:                   F(1,922)
#  Min Obs:                       22.000
#  Max Obs:                       33.000   F-statistic (robust):             32.667
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                   F(1,922)
#  Avg Obs:                       29.879
#  Min Obs:                       26.000
#  Max Obs:                       31.000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  4.5595     0.9952     4.5817     0.0000      2.6065      6.5126
#  HDI female (value)     6.6386     1.1615     5.7155     0.0000      4.3591      8.9181
#  ======================================================================================
#
#  F-test for Poolability: 81.605
#  P-value: 0.0000
#  Distribution: F(62,922)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_SSA': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.1611
#  Estimator:                   PanelOLS   R-squared (Between):              0.5514
#  No. Observations:                 930   R-squared (Within):               0.6230
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.5522
#  Time:                        14:59:06   Log-likelihood                    574.22
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      164.16
#  Entities:                          42   P-value                           0.0000
#  Avg Obs:                       22.143   Distribution:                   F(1,855)
#  Min Obs:                       4.0000
#  Max Obs:                       33.000   F-statistic (robust):             9.0427
#                                          P-value                           0.0027
#  Time periods:                      33   Distribution:                   F(1,855)
#  Avg Obs:                       28.182
#  Min Obs:                       8.0000
#  Max Obs:                       42.000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  6.4818     0.5018     12.916     0.0000      5.4968      7.4667
#  HDI female (value)     3.0359     1.0096     3.0071     0.0027      1.0544      5.0175
#  ======================================================================================
#
#  F-test for Poolability: 93.068
#  P-value: 0.0000
#  Distribution: F(73,855)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_LAC': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.4403
#  Estimator:                   PanelOLS   R-squared (Between):              0.7957
#  No. Observations:                 755   R-squared (Within):               0.8596
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.8418
#  Time:                        14:59:06   Log-likelihood                    604.86
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      545.27
#  Entities:                          29   P-value                           0.0000
#  Avg Obs:                       26.034   Distribution:                   F(1,693)
#  Min Obs:                       5.0000
#  Max Obs:                       33.000   F-statistic (robust):             48.474
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                   F(1,693)
#  Avg Obs:                       22.879
#  Min Obs:                       13.000
#  Max Obs:                       28.000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  4.3999     0.6977     6.3067     0.0000      3.0301      5.7697
#  HDI female (value)     6.8849     0.9889     6.9623     0.0000      4.9433      8.8264
#  ======================================================================================
#
#  F-test for Poolability: 58.217
#  P-value: 0.0000
#  Distribution: F(60,693)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_OC': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0918
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0519
#  No. Observations:                  66   R-squared (Within):              -0.1149
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.1104
#  Time:                        14:59:06   Log-likelihood                    178.37
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      3.1324
#  Entities:                           2   P-value                           0.0866
#  Avg Obs:                       33.000   Distribution:                    F(1,31)
#  Min Obs:                       33.000
#  Max Obs:                       33.000   F-statistic (robust):          7.455e+24
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                    F(1,31)
#  Avg Obs:                       2.0000
#  Min Obs:                       2.0000
#  Max Obs:                       2.0000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  10.971  2.214e-13  4.954e+13     0.0000      10.971      10.971
#  HDI female (value)    -0.6950  2.545e-13  -2.73e+12     0.0000     -0.6950     -0.6950
#  ======================================================================================
#
#  F-test for Poolability: 70.036
#  P-value: 0.0000
#  Distribution: F(33,31)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_SA': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.2408
#  Estimator:                   PanelOLS   R-squared (Between):              0.7146
#  No. Observations:                 248   R-squared (Within):               0.7816
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.7123
#  Time:                        14:59:06   Log-likelihood                    126.26
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      65.350
#  Entities:                           9   P-value                           0.0000
#  Avg Obs:                       27.556   Distribution:                   F(1,206)
#  Min Obs:                       12.000
#  Max Obs:                       33.000   F-statistic (robust):             3.0067
#                                          P-value                           0.0844
#  Time periods:                      33   Distribution:                   F(1,206)
#  Avg Obs:                       7.5152
#  Min Obs:                       6.0000
#  Max Obs:                       9.0000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  6.0742     1.3715     4.4288     0.0000      3.3702      8.7782
#  HDI female (value)     4.3762     2.5238     1.7340     0.0844     -0.5996      9.3520
#  ======================================================================================
#
#  F-test for Poolability: 41.677
#  P-value: 0.0000
#  Distribution: F(40,206)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_EAP': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.5889
#  Estimator:                   PanelOLS   R-squared (Between):              0.7971
#  No. Observations:                 676   R-squared (Within):               0.8905
#  Date:                Tue, May 13 2025   R-squared (Overall):              0.8156
#  Time:                        14:59:06   Log-likelihood                    463.89
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      880.89
#  Entities:                          28   P-value                           0.0000
#  Avg Obs:                       24.143   Distribution:                   F(1,615)
#  Min Obs:                       8.0000
#  Max Obs:                       33.000   F-statistic (robust):             26.814
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                   F(1,615)
#  Avg Obs:                       20.485
#  Min Obs:                       9.0000
#  Max Obs:                       28.000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  4.1005     0.9691     4.2314     0.0000      2.1974      6.0036
#  HDI female (value)     7.2721     1.4044     5.1783     0.0000      4.5142      10.030
#  ======================================================================================
#
#  F-test for Poolability: 139.50
#  P-value: 0.0000
#  Distribution: F(59,615)
#
#  Included effects: Entity, Time
#  """,
#  'GDP/HDI_Female:Region_NA': <class 'linearmodels.compat.statsmodels.Summary'>
#  """
#                            PanelOLS Estimation Summary
#  ================================================================================
#  Dep. Variable:                 logGDP   R-squared:                        0.0325
#  Estimator:                   PanelOLS   R-squared (Between):             -0.0364
#  No. Observations:                  66   R-squared (Within):              -0.0862
#  Date:                Tue, May 13 2025   R-squared (Overall):             -0.0814
#  Time:                        14:59:06   Log-likelihood                    200.36
#  Cov. Estimator:             Clustered
#                                          F-statistic:                      1.0398
#  Entities:                           2   P-value                           0.3158
#  Avg Obs:                       33.000   Distribution:                    F(1,31)
#  Min Obs:                       33.000
#  Max Obs:                       33.000   F-statistic (robust):          3.068e+25
#                                          P-value                           0.0000
#  Time periods:                      33   Distribution:                    F(1,31)
#  Avg Obs:                       2.0000
#  Min Obs:                       2.0000
#  Max Obs:                       2.0000
#
#                                   Parameter Estimates
#  ======================================================================================
#                      Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
#  --------------------------------------------------------------------------------------
#  const                  11.186  1.106e-13  1.012e+14     0.0000      11.186      11.186
#  HDI female (value)    -0.6534   1.18e-13 -5.539e+12     0.0000     -0.6534     -0.6534
#  ======================================================================================
#
#  F-test for Poolability: 64.388
#  P-value: 0.0000
#  Distribution: F(33,31)
#
#  Included effects: Entity, Time
#  """}

# %% [markdown]
# # Plots

# %%
image_path = '/Users/gianlucafilesi/Library/CloudStorage/OneDrive-EDHEC/04 THESIS/Images/Results/'

# %%
fig, ax = plt.subplots(2,2,figsize=(12, 8))
sns.histplot(data=GII, x='Gender Inequality Index (value)', bins=30, stat="density", ax=ax[0,0])
sns.kdeplot(data=GII, x='Gender Inequality Index (value)', color="red", lw=2, ax=ax[0,0])
ax[0,0].set_xlabel('Gender Inequality Index (value)')
ax[0,0].set_ylabel('Density')
ax[0,0].set_title('Distribution of Gender Inequality Index (value)')

sns.histplot(data=GDI, x='Gender Development Index (value)', bins=30, stat="density", ax=ax[0,1])
sns.kdeplot(data=GDI, x='Gender Development Index (value)', color="red", lw=2, ax=ax[0,1])
ax[0,1].set_xlabel('Gender Development Index (value)')
ax[0,1].set_ylabel('Density')
ax[0,1].set_title('Distribution of Gender Development Index (value)')

sns.histplot(data=HDI, x='Human Development Index (value)', bins=30, stat="density", ax=ax[1,0])
sns.kdeplot(data=HDI, x='Human Development Index (value)', color="red", lw=2, ax=ax[1,0])
ax[1,0].set_xlabel('Human Development Index (value)')
ax[1,0].set_ylabel('Density')
ax[1,0].set_title('Distribution of Human Development Index (value)')

sns.histplot(data=GDP, x='GDP', bins=30, stat="density", ax=ax[1,1])
sns.kdeplot(data=GDP, x='GDP', color="red", lw=2, ax=ax[1,1])
ax[1,1].set_xlabel(r'$GDP_{PC,PPP}$')
ax[1,1].set_ylabel('Density')
ax[1,1].set_title(r'Distribution of $GDP_{PC,PPP}$')

plt.tight_layout()
plt.savefig(image_path + 'Distribution.pdf', dpi=1200, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Scatter plot with trend line
sns.scatterplot(data=PrepareData(GDP_GII,HDR_idx['gii']), x=HDR_idx['gii']+'_shifted', y='logGDP', hue='region', ax=ax[0])
sns.regplot(data=PrepareData(GDP_GII,HDR_idx['gii']), x=HDR_idx['gii']+'_shifted', y='logGDP', scatter=False, ax=ax[0], color='red', line_kws={"label": "Trend Line"})
ax[0].legend(title='Region')
ax[0].set_xlabel('Gender Inequality Index (value)')
ax[0].set_ylabel(r'$\log (GDP_{PC,PPP})$')

sns.scatterplot(data=PrepareData(GDP_GII,HDR_idx['gii']), x=HDR_idx['gii']+'_shifted', y='logGDP', hue='hdicode',ax=ax[1])
sns.regplot(data=PrepareData(GDP_GII,HDR_idx['gii']), x=HDR_idx['gii'], y='logGDP', scatter=False, ax=ax[1], color='red', line_kws={"label": "Trend Line"})
ax[1].legend(title='HDI Level')
ax[1].set_xlabel('Gender Inequality Index (value)')
ax[1].set_ylabel(r'$\log (GDP_{PC,PPP})$')

plt.savefig(image_path + 'GDP_GII.pdf', dpi=1200, bbox_inches='tight')
plt.show()

C = PrepareData(GDP_GII,HDR_idx['gii'])
C = C[[HDR_idx['gii']+'_shifted','logGDP']]
C = C.dropna()
print(C.corr())
# Out:
#                                          Gender Inequality Index (value)_shifted  \
# Gender Inequality Index (value)_shifted                                 1.000000
# logGDP                                                                 -0.779201
#
#                                            logGDP
# Gender Inequality Index (value)_shifted -0.779201
# logGDP                                   1.000000

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Scatter plot with trend line
sns.scatterplot(data=Panel_GII, x=HDR_idx['gii']+'_shifted', y='logGDP', hue='region', ax=ax[0])
sns.regplot(data=Panel_GII, x=HDR_idx['gii'], y='logGDP', scatter=False, ax=ax[0], color='red', line_kws={"label": "Trend Line"})
ax[0].legend(title='Region')
ax[0].set_xlabel('Gender Inequality Index (value)')
ax[0].set_ylabel(r'$\log (GDP_{PC,PPP})$')

sns.scatterplot(data=Panel_GII, x=HDR_idx['gii']+'_shifted', y='logGDP', hue='hdicode',ax=ax[1])
sns.regplot(data=Panel_GII, x=HDR_idx['gii'], y='logGDP', scatter=False, ax=ax[1], color='red', line_kws={"label": "Trend Line"})
ax[1].legend(title='HDI Level')
ax[1].set_xlabel('Gender Inequality Index (value)')
ax[1].set_ylabel(r'$\log (GDP_{PC,PPP})$')

plt.savefig(image_path + 'GDP_GII_noAS.pdf', dpi=1200, bbox_inches='tight')
plt.show()

C = Panel_GII[[HDR_idx['gii']+'_shifted','logGDP']]
C = C.dropna()
print(C.corr())
# Out:
#                                          Gender Inequality Index (value)_shifted  \
# Gender Inequality Index (value)_shifted                                 1.000000
# logGDP                                                                 -0.836058
#
#                                            logGDP
# Gender Inequality Index (value)_shifted -0.836058
# logGDP                                   1.000000

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Scatter plot with trend line
sns.scatterplot(data=Panel_GDI, x='HDI female (value)'+'_shifted', y='logGDP', hue='region', ax=ax[0])
sns.regplot(data=Panel_GDI, x='HDI female (value)'+'_shifted', y='logGDP', scatter=False, ax=ax[0], color='red', line_kws={"label": "Trend Line"})
ax[0].legend(title='Region')
ax[0].set_xlabel('HDI female (value)')
ax[0].set_ylabel(r'$\log (GDP_{PC,PPP})$')

sns.scatterplot(data=Panel_GDI, x='HDI female (value)'+'_shifted', y='logGDP', hue='hdicode',ax=ax[1])
sns.regplot(data=Panel_GDI, x='HDI female (value)'+'_shifted', y='logGDP', scatter=False, ax=ax[1], color='red', line_kws={"label": "Trend Line"})
ax[1].legend(title='HDI Level')
ax[1].set_xlabel('HDI female (value)')
ax[1].set_ylabel(r'$\log (GDP_{PC,PPP})$')


plt.savefig(image_path + 'GDP_HDI_female.pdf', dpi=1200, bbox_inches='tight')
plt.show()

C = Panel_GDI[['HDI female (value)'+'_shifted','logGDP']]
C = C.dropna()
print(C.corr())
# Out:
#                             HDI female (value)_shifted   logGDP
# HDI female (value)_shifted                     1.00000  0.91137
# logGDP                                         0.91137  1.00000

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=Panel_HDI, x=HDR_idx['hdi']+'_shifted', y='logGDP', hue='region',)
sns.regplot(data=Panel_HDI, x=HDR_idx['hdi']+'_shifted', y='logGDP', scatter=False, color='red', line_kws={"label": "Trend Line"})
plt.ylabel(r'$\log (GDP_{PC,PPP})$')
plt.xlabel('Human Development Index (value)')
plt.legend(title='Region')

plt.savefig(image_path + 'GDP_HDI.pdf', dpi=1200, bbox_inches='tight')
plt.show()

C = Panel_HDI[[HDR_idx['hdi']+'_shifted','logGDP']]
C = C.dropna()
print(C.corr())
# Out:
#                                          Human Development Index (value)_shifted  \
# Human Development Index (value)_shifted                                 1.000000
# logGDP                                                                  0.927144
#
#                                            logGDP
# Human Development Index (value)_shifted  0.927144
# logGDP                                   1.000000

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=Panel_HDI_GII, x=HDR_idx['gii']+'_shifted', y=HDR_idx['hdi'], hue='region')
sns.regplot(data=Panel_HDI_GII, x=HDR_idx['gii']+'_shifted', y=HDR_idx['hdi'], scatter=False, color='red', line_kws={"label": "Trend Line"})
plt.ylabel(HDR_idx['hdi'])
plt.xlabel(HDR_idx['gii'])
plt.legend(title='Region')

plt.savefig(image_path + 'HDI_GII.pdf', dpi=1200, bbox_inches='tight')
plt.show()

C = Panel_HDI_GII[[HDR_idx['gii']+'_shifted',HDR_idx['hdi']]]
C = C.dropna()
print(C.corr())
# Out:
#                                          Gender Inequality Index (value)_shifted  \
# Gender Inequality Index (value)_shifted                                 1.000000
# Human Development Index (value)                                        -0.868187
#
#                                          Human Development Index (value)
# Gender Inequality Index (value)_shifted                        -0.868187
# Human Development Index (value)                                 1.000000

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=Panel_GDI, y='HDI female (value)'+'_shifted', x='HDI male (value)', hue='region')
plt.plot([0.2, 1], [0.2, 1], color='black', linestyle='--')
plt.legend(title='Region')

plt.savefig(image_path + 'HDI_Female_vs_Male.pdf', dpi=1200, bbox_inches='tight')
plt.show()

# %%
M = Panel_GDI.copy() # Drop rows with NaN values
M.dropna(subset = ['HDI female (value)','HDI male (value)'])
np.corrcoef(M['HDI female (value)'], M['HDI male (value)'])
# Out:
# array([[1.        , 0.97706484],
#        [0.97706484, 1.        ]])

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=Panel_GII_Schooling, x='Total net attendance rate, upper secondary, female (%)', y='logGDP', hue='region')
plt.ylabel(r'$\log (GDP_{PC,PPP})$')
plt.legend(title='Region')
plt.show()
